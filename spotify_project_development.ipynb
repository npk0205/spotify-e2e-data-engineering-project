# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="f600c5db07b94fe88399e5e98207ca60", client_secret="9f93775425c44d1285769d0c013ebf1a")

# %%
## spotify object
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f&nd=1&dlsi=6c8f34a592794165"

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0].strip()

# %%
playlist_URI
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
data = sp.playlist_tracks(playlist_URI)

# %% [markdown]
# ## let's transform the data

# %%
data['items'][0]['track']['album']['id']
# Out:
# '10FLjwfpbxLmW8c25Xyc2N'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Die With A Smile'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-08-16'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'

# %%
## will exract all of these data for all albums using loop
for row in data['items']:
    album_id = row['track']['album']['id']
    print(album_id)
# Out:
# 10FLjwfpbxLmW8c25Xyc2N
# 7aJuG4TFXa2hmE4z1yxc3n
# 2IRxVVqbSbqHJo8Zx50LYn
# 15XcLhiVMlSOipUddTNDnr
# 3iPSVi54hsacKKl1xIR2eH
# 3iPSVi54hsacKKl1xIR2eH
# 1WAjjRMfZjEXtB0lQrAw6Q
# 5ylbxH7EqpsmHZCRuiYewS
# 3iPSVi54hsacKKl1xIR2eH
# 6W0Gabv5f3ugnckc6YgfJQ
# 168CdR21lfn0TTyw1Pkdcm
# 3iPSVi54hsacKKl1xIR2eH
# 0DLvFVIfwt3OHdK9kGeEM3
# 7nacKlk586eLRBSIsrk9DB
# 3Su6Sgi0YjcUFuCzjLKYYq
# 48qd9sU3xqYJbKaxHCciJL
# 4xkM0BwLM9H2IUcbYzpcBI
# 7aJuG4TFXa2hmE4z1yxc3n
# 7tzVd1fwkxsorytCBjEJkU
# 68CN2LzY8MoxO2udy2C22e
# 78bpIziExqiI9qztvNFlQu
# 3ThlxfLSy4bfKzxWqmC7VN
# 4BbsHmXEghoPPevQjPnHXx
# 4sD1qg4jwTZR4mvR4Iflk5
# 18NOKLkZETa4sWwLMIm0UZ
# 6MikZBKCtKfPM4439yzBRz
# 5EYKrEDnKhhcNxGedaRQeK
# 0EiI8ylL0FmWWpgHVTsZjZ
# 6ZG5lRT77aJ3btmArcykra
# 5JjnoGJyOxfSZUZtk2rRwZ
# 2Z1gnUf3nbn6DtwZSUIH54
# 27GWSFRITD8JJcSGMgEfTN
# 4JDXBZdRPId4devseaAOKH
# 2lIzIH2mQQ0ItgkJKefQMp
# 4Gfnly5CzMJQqkUFfoHaP3
# 1NAmidJlEaVgA3MpcPFYGq
# 6MikZBKCtKfPM4439yzBRz
# 5nzSCZ7NhKvAysI0tmNOdD
# 56bdWeO40o3WfAD2Lja4dl
# 2nkto6YNI4rUYTLqEwWJ3o
# ...

# %%
## loop is working fine so lets do it for all data
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
##creating dictionary
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'name': 'Die With A Smile',
#   'release_date': '2024-08-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '2IRxVVqbSbqHJo8Zx50LYn',
#   'name': 'Timeless',
#   'release_date': '2024-09-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2IRxVVqbSbqHJo8Zx50LYn'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'name': 'MUSE',
#   'release_date': '2024-07-19',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
# ...

# %%
data['items'][0]['track']['artists'][0]['id']
# Out:
# '1HY2Jd0NmPuamShAr6KMms'

# %%
artist_list = []
for row in data['items']:
    for key,value in row.items():
        if key == "track":
            for atrist in value['artists']:
                artist_dictionary = {'artist_id':atrist['id'], 'artist_name':atrist['name'], 'external_url':atrist['href']}
                artist_list.append(artist_dictionary)

# %%
artist_list
# Out:
# [{'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_url': 'https://api.spotify.com/v1/artists/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'external_url': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '2plbrEY59IikOBgBGLjaoe',
#   'song_name': 'Die With A Smile',
#   'duration_ms': 251667,
#   'url': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe',
#   'popularity': 100,
#   'song_added': '2024-10-04T12:42:06Z',
#   'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '6dOtVTDdiauQNBQEDOtlAB',
#   'song_name': 'BIRDS OF A FEATHER',
#   'duration_ms': 210373,
#   'url': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB',
#   'popularity': 98,
#   'song_added': '2024-10-04T12:42:06Z',
#   'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '1Es7AUAhQvapIcoh3qMKDL',
#   'song_name': 'Timeless (with Playboi Carti)',
#   'duration_ms': 256000,
#   'url': 'https://open.spotify.com/track/1Es7AUAhQvapIcoh3qMKDL',
#   'popularity': 90,
#   'song_added': '2024-10-04T12:42:06Z',
#   'album_id': '2IRxVVqbSbqHJo8Zx50LYn',
#   'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ'},
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                  name release_date  total_tracks  \
# 0  10FLjwfpbxLmW8c25Xyc2N      Die With A Smile   2024-08-16             1
# 1  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT   2024-05-17            10
# 2  2IRxVVqbSbqHJo8Zx50LYn              Timeless   2024-09-27             1
# 3  15XcLhiVMlSOipUddTNDnr                  MUSE   2024-07-19             7
# 4  3iPSVi54hsacKKl1xIR2eH        Short n' Sweet   2024-08-23            12
#
#                                                  url
# 0  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 1  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2  https://open.spotify.com/album/2IRxVVqbSbqHJo8...
# 3  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 4  https://open.spotify.com/album/3iPSVi54hsacKKl...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
##dropping duplicates
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                  artist_id    artist_name  \
# 0   1HY2Jd0NmPuamShAr6KMms      Lady Gaga
# 1   0du5cEVh5yTK9QJze8zA0C     Bruno Mars
# 2   6qqNVTkY8uBg9cP3Jd7DAH  Billie Eilish
# 3   1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 4   699OTQXzgjhIYAHMy9RyPD  Playboi Carti
# ..                     ...            ...
# 62  2tIP7SsRs7vjIcLrU85W8J  The Kid LAROI
# 63  5HK6QtizXJzCmoYTkvFRik          Ndotz
# 64  5eumcnUkdmGvkvcsx1WFNG  Tito Double P
# 65  12GqGscKJx3aE4t07u7eVZ     Peso Pluma
# 66  3bO19AOone0ubCsfDXDtYt    Myles Smith
#
#                                          external_url
# 0   https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 1   https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2   https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 3   https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 4   https://api.spotify.com/v1/artists/699OTQXzgjh...
# ..                                                ...
# 62  https://api.spotify.com/v1/artists/2tIP7SsRs7v...
# ...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                    song_id                                          song_name  \
# 0   2plbrEY59IikOBgBGLjaoe                                   Die With A Smile
# 1   6dOtVTDdiauQNBQEDOtlAB                                 BIRDS OF A FEATHER
# 2   1Es7AUAhQvapIcoh3qMKDL                      Timeless (with Playboi Carti)
# 3   7tI8dRuH2Yc6RuoTjxo4dU                                                Who
# 4   5G2f63n7IPVPPjfNIGih7Q                                              Taste
# 5   2HRqTpkrJO5ggZyyK6NPWz                                           Espresso
# 6   0WbMK4wrZ1wFSty9F7FCgu                                   Good Luck, Babe!
# 7   6WatFBLVB0x077xWeoVc2k                       Si Antes Te Hubiera Conocido
# 8   2tHwzyyOLoWSFqYNjeVMzj                               Please Please Please
# 9   2PnlsTsOTLE5jnBnNe2K0A                              The Emptiness Machine
# 10  3xkHsmpQCBMytMJNiDf3Ii                                   Beautiful Things
# ...

# %%
song_df = song_df.drop_duplicates(subset=['song_id'])

# %%
artist_df.head()
# Out:
#                 artist_id    artist_name  \
# 0  1HY2Jd0NmPuamShAr6KMms      Lady Gaga
# 1  0du5cEVh5yTK9QJze8zA0C     Bruno Mars
# 2  6qqNVTkY8uBg9cP3Jd7DAH  Billie Eilish
# 3  1Xyo4u8uXC1ZmMpatF05PJ     The Weeknd
# 4  699OTQXzgjhIYAHMy9RyPD  Playboi Carti
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 1  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2  https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 3  https://api.spotify.com/v1/artists/1Xyo4u8uXC1...
# 4  https://api.spotify.com/v1/artists/699OTQXzgjh...

# %%
album_df.head()
# Out:
#                  album_id                  name release_date  total_tracks  \
# 0  10FLjwfpbxLmW8c25Xyc2N      Die With A Smile   2024-08-16             1
# 1  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT   2024-05-17            10
# 2  2IRxVVqbSbqHJo8Zx50LYn              Timeless   2024-09-27             1
# 3  15XcLhiVMlSOipUddTNDnr                  MUSE   2024-07-19             7
# 4  3iPSVi54hsacKKl1xIR2eH        Short n' Sweet   2024-08-23            12
#
#                                                  url
# 0  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 1  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2  https://open.spotify.com/album/2IRxVVqbSbqHJo8...
# 3  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 4  https://open.spotify.com/album/3iPSVi54hsacKKl...

# %%
song_df.head()
# Out:
#                   song_id                      song_name  duration_ms  \
# 0  2plbrEY59IikOBgBGLjaoe               Die With A Smile       251667
# 1  6dOtVTDdiauQNBQEDOtlAB             BIRDS OF A FEATHER       210373
# 2  1Es7AUAhQvapIcoh3qMKDL  Timeless (with Playboi Carti)       256000
# 3  7tI8dRuH2Yc6RuoTjxo4dU                            Who       170887
# 4  5G2f63n7IPVPPjfNIGih7Q                          Taste       157279
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2plbrEY59IikOBg...         100
# 1  https://open.spotify.com/track/6dOtVTDdiauQNBQ...          98
# 2  https://open.spotify.com/track/1Es7AUAhQvapIco...          90
# 3  https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...          93
# 4  https://open.spotify.com/track/5G2f63n7IPVPPjf...          95
#
#              song_added                album_id               artist_id
# 0  2024-10-04T12:42:06Z  10FLjwfpbxLmW8c25Xyc2N  1HY2Jd0NmPuamShAr6KMms
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     object
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ KB

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      44 non-null     object
#  1   name          44 non-null     object
#  2   release_date  44 non-null     datetime64[ns]
#  3   total_tracks  44 non-null     int64
#  4   url           44 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.1+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB
